# %% [markdown]
# ### The goal of this exercize is to use the dataset of Sleep & Doomscrolling Habits from Kaggle to ask questions and use SQL to answer said questions.

# %%
# First we will Import our resources and CSV file to perform our queries on

# %%
import duckdb as db

# %%
doom = db.read_csv("sleep_doomscrolling_habits.csv")
type(doom)
# Out:
# _duckdb.DuckDBPyRelation

# %%
sql = db.sql

# %%
#check to see what our table looks like
sql("""SELECT * 
FROM doom LIMIT 10""")
# Out:
# ┌───────────────┬───────┬─────────────────────────────┬───────────────────────────────┬───────────────────────────────┬────────────────────────────────┬───────────────────────┬───────────────────────┬─────────────────────────┬────────────────────────────┬───────────────┬──────────────┬─────────────────────┬───────────────────────┬──────────────────────────┬────────────────────────┬──────────────────────────┬───────────────────────────────┬─────────────────────────┬───────────────────┬────────────────────┬────────────────┬──────────────────────────────┬────────────────────────┬─────────────────┬────────────────────────┬────────────────────────────────┬─────────────────────────┬──────────────┬────────────────────────┐
# │ respondent_id │  age  │ bedtime_screen_time_minutes │ total_daily_screen_time_hours │ doomscroll_sessions_per_night │ avg_doomscroll_session_minutes │ sleep_hours_per_night │ sleep_latency_minutes │ number_of_night_wakeups │ caffeine_intake_mg_per_day │ anxiety_score │ stress_score │ sleep_quality_score │ daytime_fatigue_score │ number_of_news_apps_used │ phone_checks_per_night │ exercise_minutes_per_day │ days_since_last_digital_detox │ weekly_sleep_debt_hours │      gender       │ occupation_status  │ country_region │ primary_device_used_at_night │  bedtime_routine_type  │ uses_night_mode │ keeps_phone_in_bedroom │ consumes_negative_news_content │ uses_sleep_tracking_app │ doomscroller │ sleep_quality_category │
# │    varchar    │ int64 │           double            │            double             │             int64             │             double             │        double         │        double         │          int64          │           double           │     int64     │    int64     │       double        │         int64         │          int64           │         int64          │          double          │            double             │         double          │      varchar      │      varchar       │    varchar     │           varchar            │        varchar         │     boolean     │        boolean         │            boolean             │         boolean         │   boolean    │        varchar         │
# ├───────────────┼───────┼─────────────────────────────┼───────────────────────────────┼───────────────────────────────┼────────────────────────────────┼───────────────────────┼───────────────────────┼─────────────────────────┼────────────────────────────┼───────────────┼──────────────┼─────────────────────┼───────────────────────┼──────────────────────────┼────────────────────────┼──────────────────────────┼───────────────────────────────┼─────────────────────────┼───────────────────┼────────────────────┼────────────────┼──────────────────────────────┼────────────────────────┼─────────────────┼────────────────────────┼────────────────────────────────┼─────────────────────────┼──────────────┼────────────────────────┤
# │ D30000        │    22 │                        13.0 │                          1.85 │                             2 │                            5.4 │                   8.1 │                  19.0 │                       2 │                      155.0 │             5 │            7 │                 5.0 │                     6 │                        3 │                      3 │                    103.0 │                           9.0 │                     0.7 │ Male              │ Unemployed         │ Germany        │ Tablet                       │ Meditation/Journaling  │ true            │ true                   │ true                           │ false                   │ true         │ Good                   │
# │ D30001        │    18 │                        90.0 │                          3.61 │                             3 │                           29.6 │                   7.0 │                  31.0 │                       3 │                       82.0 │             5 │            6 │                 3.0 │                     9 │                        2 │                      3 │                     28.0 │                          24.0 │                     7.5 │ Male              │ Student            │ India          │ Smartphone                   │ Meditation/Journaling  │ false           │ true                   │ true                           │ false                   │ true         │ Poor                   │
# │ D30002        │    37 │                        51.0 │                          5.15 │                             3 │                           15.5 │                   7.1 │                  24.0 │                       2 │                       49.0 │             2 │            2 │                 5.0 │                     8 │                        0 │                      3 │                     11.0 │                          15.0 │                     2.9 │ Prefer not to say │ Student            │ India          │ Laptop                       │ Reading                │ false           │ true                   │ false                          │ true                    │ true         │ Fair                   │
# │ D30003        │    27 │                        53.0 │                          3.74 │                             0 │                           51.4 │                   8.4 │                  35.0 │                       0 │                       42.0 │             6 │            6 │                 5.0 │                     4 │                        1 │                      0 │                     61.0 │                          13.0 │                     0.0 │ Prefer not to say │ NULL               │ United States  │ Smartphone                   │ No Fixed Routine       │ false           │ true                   │ true                           │ false                   │ false        │ Fair                   │
# │ D30004        │    17 │                        67.0 │                          6.09 │                             2 │                           32.2 │                   7.2 │                  19.0 │                       1 │                       76.0 │             5 │            7 │                 5.0 │                     7 │                        3 │                      3 │                     23.0 │                          19.0 │                     5.4 │ Prefer not to say │ Employed Part-time │ United States  │ Smartphone                   │ Watching Videos        │ false           │ false                  │ false                          │ false                   │ false        │ Fair                   │
# │ D30005        │    21 │                        81.0 │                           5.2 │                             4 │                           19.5 │                   7.9 │                  39.0 │                       2 │                       61.0 │             5 │            6 │                 5.0 │                     7 │                        0 │                      2 │                     37.0 │                          84.0 │                     4.3 │ Female            │ Student            │ Nigeria        │ Smartphone                   │ Watching Videos        │ false           │ true                   │ false                          │ false                   │ true         │ Fair                   │
# │ D30006        │    34 │                        56.0 │                          3.75 │                             3 │                           18.7 │                   8.8 │                  45.0 │                       1 │                      166.0 │             3 │            6 │                 5.0 │                     7 │                        0 │                      2 │                     28.0 │                          59.0 │                     0.0 │ Female            │ Employed Full-time │ Philippines    │ Smartphone                   │ Scrolling Social Media │ false           │ true                   │ false                          │ false                   │ true         │ Good                   │
# │ D30007        │    26 │                        40.0 │                          2.41 │                             3 │                           13.7 │                   7.7 │                  36.0 │                       2 │                       54.0 │             4 │            4 │                NULL │                     8 │                        0 │                      2 │                     71.0 │                          17.0 │                     4.5 │ Male              │ Student            │ United Kingdom │ Smartphone                   │ Scrolling Social Media │ true            │ true                   │ true                           │ true                    │ true         │ Poor                   │
# │ D30008        │    32 │                        77.0 │                          3.38 │                             4 │                           19.2 │                   7.8 │                  29.0 │                       1 │                      127.0 │             4 │            3 │                 5.0 │                     5 │                        2 │                      1 │                     12.0 │                           7.0 │                     4.8 │ Female            │ Employed Full-time │ Germany        │ Smartphone                   │ Reading                │ true            │ true                   │ false                          │ false                   │ true         │ Fair                   │
# │ D30009        │    34 │                        23.0 │                          2.46 │                             2 │                            7.8 │                   6.4 │                  18.0 │                       3 │                       97.0 │             4 │            6 │                 5.0 │                     6 │                        0 │                      5 │                     62.0 │                          34.0 │                    12.7 │ Male              │ Employed Full-time │ Philippines    │ Tablet                       │ Reading                │ false           │ false                  │ false                          │ false                   │ false        │ Poor                   │
# └───────────────┴───────┴─────────────────────────────┴───────────────────────────────┴───────────────────────────────┴────────────────────────────────┴───────────────────────┴───────────────────────┴─────────────────────────┴────────────────────────────┴───────────────┴──────────────┴─────────────────────┴───────────────────────┴──────────────────────────┴────────────────────────┴──────────────────────────┴───────────────────────────────┴─────────────────────────┴───────────────────┴────────────────────┴────────────────┴──────────────────────────────┴────────────────────────┴─────────────────┴────────────────────────┴────────────────────────────────┴─────────────────────────┴──────────────┴────────────────────────┘
#   10 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                30 columns

# %% [markdown]
# ### Now we need to ask ourselves, what do we want to know?
# #### The initial question I want to ask is, What is the average amount of sleep per age group?

# %%
sql("""
SELECT 
    age,
    ROUND(AVG(sleep_hours_per_night),2) AS average_sleep
FROM doom
GROUP BY age
ORDER BY average_sleep ASC;
""")
# Out:
# ┌───────┬───────────────┐
# │  age  │ average_sleep │
# │ int64 │    double     │
# ├───────┼───────────────┤
# │    54 │           6.5 │
# │    42 │          7.09 │
# │    37 │          7.12 │
# │    35 │          7.14 │
# │    28 │          7.17 │
# │    30 │          7.23 │
# │    34 │          7.24 │
# │    40 │          7.26 │
# │    24 │          7.28 │
# │    43 │          7.29 │
# │     · │            ·  │
# │     · │            ·  │
# │     · │            ·  │
# │    36 │          7.58 │
# │    31 │          7.58 │
# │    39 │          7.62 │
# │    50 │          7.65 │
# │    29 │          7.68 │
# │    32 │          7.69 │
# │    41 │           7.7 │
# │    19 │          7.72 │
# │    44 │          7.88 │
# │    49 │           7.9 │
# └───────┴───────────────┘
#   36 rows     2 columns
#   (20 shown)

# %%
#this doesn't look very good and is a little hard to read, lets check if gender plays a part.
sql("""
SELECT gender,
ROUND(AVG(sleep_hours_per_night),2) AS average_sleep
FROM doom
GROUP BY gender
""")
# Out:
# ┌───────────────────┬───────────────┐
# │      gender       │ average_sleep │
# │      varchar      │    double     │
# ├───────────────────┼───────────────┤
# │ Prefer not to say │          7.44 │
# │ Male              │          7.39 │
# │ Female            │          7.44 │
# └───────────────────┴───────────────┘

# %%
#lets group them by age ranges; since most of our data is between 15 and 38 we'll group everything over 37 and Under 18, I want to break it up into even chunks of 5 years.
sql("""
SELECT
    CASE
        WHEN age < 18 THEN 'Under 18'
        WHEN age BETWEEN 18 AND 22 THEN '18-22'
        WHEN age BETWEEN 23 AND 27 THEN '23-27'
        WHEN age BETWEEN 28 AND 32 THEN '28-32'
        WHEN age BETWEEN 33 AND 37 THEN '33-37'
        ELSE 'Over 37'
    END AS age_range,
    ROUND(AVG(sleep_hours_per_night),2) AS average_sleep
FROM doom
GROUP BY age_range
ORDER BY average_sleep DESC;    
""")
# Out:
# ┌───────────┬───────────────┐
# │ age_range │ average_sleep │
# │  varchar  │    double     │
# ├───────────┼───────────────┤
# │ 18-22     │          7.48 │
# │ 28-32     │          7.46 │
# │ Over 37   │          7.43 │
# │ 23-27     │          7.42 │
# │ Under 18  │           7.4 │
# │ 33-37     │          7.28 │
# └───────────┴───────────────┘

# %% [markdown]
# #### We can see that the 18-22 age range has the best average sleep
# ##### Are there any factors that affect that? Let's check how much caffeine everyone drinks and bedtime screen time to see if they have an impact on the average

# %%
sql("""
SELECT
    CASE
        WHEN age < 18 THEN 'Under 18'
        WHEN age BETWEEN 18 AND 22 THEN '18-22'
        WHEN age BETWEEN 23 AND 27 THEN '23-27'
        WHEN age BETWEEN 28 AND 32 THEN '28-32'
        WHEN age BETWEEN 33 AND 37 THEN '33-37'
        ELSE 'Over 37'
    END AS age_range,
    ROUND(AVG(sleep_hours_per_night),2) AS average_sleep,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_betime_screen,
    ROUND(AVG(caffeine_intake_mg_per_day),2) AS average_daily_caffeine_mg
FROM doom
GROUP BY age_range
ORDER BY average_sleep DESC;    
""")
# Out:
# ┌───────────┬───────────────┬───────────────────────┬───────────────────────────┐
# │ age_range │ average_sleep │ average_betime_screen │ average_daily_caffeine_mg │
# │  varchar  │    double     │        double         │          double           │
# ├───────────┼───────────────┼───────────────────────┼───────────────────────────┤
# │ 18-22     │          7.48 │                 50.84 │                    115.67 │
# │ 28-32     │          7.46 │                 52.19 │                    122.96 │
# │ Over 37   │          7.43 │                  49.2 │                    114.62 │
# │ 23-27     │          7.42 │                 48.36 │                    117.79 │
# │ Under 18  │           7.4 │                 49.31 │                    121.07 │
# │ 33-37     │          7.28 │                 50.21 │                    131.22 │
# └───────────┴───────────────┴───────────────────────┴───────────────────────────┘

# %%
#those didn't seem to have much of an affect on how much sleep each person gets, let's see if waking up in the middle of the night and number of phone checks per night has an effect.
sql("""
SELECT
    CASE
        WHEN age < 18 THEN 'Under 18'
        WHEN age BETWEEN 18 AND 22 THEN '18-22'
        WHEN age BETWEEN 23 AND 27 THEN '23-27'
        WHEN age BETWEEN 28 AND 32 THEN '28-32'
        WHEN age BETWEEN 33 AND 37 THEN '33-37'
        ELSE 'Over 37'
    END AS age_range,
    ROUND(AVG(sleep_hours_per_night),2) AS average_sleep,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_betime_screen,
    ROUND(AVG(caffeine_intake_mg_per_day),2) AS average_daily_caffeine_mg,
    ROUND(AVG(number_of_night_wakeups),2) AS average_wakeups,
    ROUND(AVG(phone_checks_per_night),2) AS average_phone_checks
FROM doom
GROUP BY age_range
ORDER BY average_sleep DESC;    
""")
# Out:
# ┌───────────┬───────────────┬───────────────────────┬───────────────────────────┬─────────────────┬──────────────────────┐
# │ age_range │ average_sleep │ average_betime_screen │ average_daily_caffeine_mg │ average_wakeups │ average_phone_checks │
# │  varchar  │    double     │        double         │          double           │     double      │        double        │
# ├───────────┼───────────────┼───────────────────────┼───────────────────────────┼─────────────────┼──────────────────────┤
# │ 18-22     │          7.48 │                 50.84 │                    115.67 │            1.52 │                 2.62 │
# │ 28-32     │          7.46 │                 52.19 │                    122.96 │            1.44 │                 2.49 │
# │ Over 37   │          7.43 │                  49.2 │                    114.62 │            1.33 │                 2.53 │
# │ 23-27     │          7.42 │                 48.36 │                    117.79 │            1.38 │                  2.4 │
# │ Under 18  │           7.4 │                 49.31 │                    121.07 │            1.39 │                 2.41 │
# │ 33-37     │          7.28 │                 50.21 │                    131.22 │            1.37 │                 2.44 │
# └───────────┴───────────────┴───────────────────────┴───────────────────────────┴─────────────────┴──────────────────────┘

# %% [markdown]
# ### Let's change how we're looking at this, averaging out the age groups doesnt seem to be showing us data that shows real changes.
# #### Let's group by how many hours of sleep people are getting and their screen time.

# %%
sql("""
SELECT
    CASE
        WHEN sleep_hours_per_night < 6 THEN 'Under 6'
        WHEN sleep_hours_per_night BETWEEN 6 AND 7 THEN '6-7'
        WHEN sleep_hours_per_night BETWEEN 7 AND 8 THEN '7-8'
        WHEN sleep_hours_per_night BETWEEN 8 AND 9 THEN '8-9'
        ELSE 'Over 9'
    END AS sleep_time,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_screen
FROM doom,
GROUP BY Sleep_time
order by average_screen DESC;
""")
# Out:
# ┌────────────┬────────────────┐
# │ sleep_time │ average_screen │
# │  varchar   │     double     │
# ├────────────┼────────────────┤
# │ Under 6    │         100.87 │
# │ 6-7        │          63.21 │
# │ 7-8        │          45.99 │
# │ 8-9        │          34.69 │
# │ Over 9     │          31.31 │
# └────────────┴────────────────┘

# %%
#We can really see here that screen time before bed can affect how long you sleep, The amount of sleep trends down the more screentime there is before bed. Let's see if anything else affects it that much.
sql("""
SELECT
    CASE
        WHEN sleep_hours_per_night < 6 THEN 'Under 6'
        WHEN sleep_hours_per_night BETWEEN 6 AND 7 THEN '6-7'
        WHEN sleep_hours_per_night BETWEEN 7 AND 8 THEN '7-8'
        WHEN sleep_hours_per_night BETWEEN 8 AND 9 THEN '8-9'
        ELSE 'Over 9'
    END AS sleep_time,
    ROUND(AVG(exercise_minutes_per_day),2) AS average_exercise,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_screen,
    ROUND(AVG(caffeine_intake_mg_per_day),2) AS average_caffeine,
    ROUND(AVG(stress_score)) AS average_stress
FROM doom
GROUP BY sleep_time
ORDER BY average_screen DESC
""")
# Out:
# ┌────────────┬──────────────────┬────────────────┬──────────────────┬────────────────┐
# │ sleep_time │ average_exercise │ average_screen │ average_caffeine │ average_stress │
# │  varchar   │      double      │     double     │      double      │     double     │
# ├────────────┼──────────────────┼────────────────┼──────────────────┼────────────────┤
# │ Under 6    │            50.79 │         100.87 │           125.69 │            7.0 │
# │ 6-7        │            49.45 │          63.21 │           119.62 │            6.0 │
# │ 7-8        │            54.77 │          45.99 │           119.04 │            6.0 │
# │ 8-9        │            54.95 │          34.69 │           126.31 │            6.0 │
# │ Over 9     │             59.2 │          31.31 │           120.14 │            6.0 │
# └────────────┴──────────────────┴────────────────┴──────────────────┴────────────────┘

# %%
#Looking at those results, it isn't super conclusive if exercise greatly affects your sleep time, lets look at quality of sleep as well. 
#caffeine doesn't seem to affect total sleep that much and stress is pretty even across the board, with under 6 being highest but also smallest pool
sql("""
SELECT
    CASE
        WHEN sleep_hours_per_night < 6 THEN 'Under 6'
        WHEN sleep_hours_per_night BETWEEN 6 AND 7 THEN '6-7'
        WHEN sleep_hours_per_night BETWEEN 7 AND 8 THEN '7-8'
        WHEN sleep_hours_per_night BETWEEN 8 AND 9 THEN '8-9'
        ELSE 'Over 9'
    END AS sleep_time,
    ROUND(AVG(exercise_minutes_per_day),2) AS average_exercise,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_screen,
    ROUND(AVG(caffeine_intake_mg_per_day),2) AS average_caffeine,
    ROUND(AVG(stress_score)) AS average_stress,
    sleep_quality_category
FROM doom
GROUP BY sleep_time, sleep_quality_category
ORDER BY sleep_quality_category
""")
# Out:
# ┌────────────┬──────────────────┬────────────────┬──────────────────┬────────────────┬────────────────────────┐
# │ sleep_time │ average_exercise │ average_screen │ average_caffeine │ average_stress │ sleep_quality_category │
# │  varchar   │      double      │     double     │      double      │     double     │        varchar         │
# ├────────────┼──────────────────┼────────────────┼──────────────────┼────────────────┼────────────────────────┤
# │ Under 6    │             49.0 │         100.33 │            137.0 │            6.0 │ Fair                   │
# │ 7-8        │             52.3 │          47.68 │           110.11 │            6.0 │ Fair                   │
# │ 8-9        │            53.06 │          35.96 │           120.08 │            6.0 │ Fair                   │
# │ Over 9     │            61.86 │           26.0 │            128.0 │            6.0 │ Fair                   │
# │ 6-7        │            53.28 │          49.37 │           132.79 │            6.0 │ Fair                   │
# │ 6-7        │            49.82 │          38.92 │           123.72 │            6.0 │ Good                   │
# │ 8-9        │             56.4 │           31.7 │           126.29 │            6.0 │ Good                   │
# │ 7-8        │            58.65 │          35.37 │           118.98 │            6.0 │ Good                   │
# │ Under 6    │            33.67 │           55.0 │           170.33 │            7.0 │ Good                   │
# │ Over 9     │            56.88 │          35.44 │           115.78 │            6.0 │ Good                   │
# │ Under 6    │            53.17 │         106.67 │           118.39 │            7.0 │ Poor                   │
# │ 7-8        │             53.1 │          58.26 │           132.75 │            6.0 │ Poor                   │
# │ 6-7        │            47.57 │          77.32 │            111.8 │            6.0 │ Poor                   │
# │ 8-9        │            52.96 │          44.32 │           139.38 │            6.0 │ Poor                   │
# └────────────┴──────────────────┴────────────────┴──────────────────┴────────────────┴────────────────────────┘
#   14 rows                                                                                           6 columns

# %%
#It does not look like exercise affects the quality of sleep, it does seem like the lower the screentime the better the sleep though. Maybe the type of screen matters?
sql("""
SELECT
    CASE
        WHEN sleep_hours_per_night < 6 THEN 'Under 6'
        WHEN sleep_hours_per_night BETWEEN 6 AND 7 THEN '6-7'
        WHEN sleep_hours_per_night BETWEEN 7 AND 8 THEN '7-8'
        WHEN sleep_hours_per_night BETWEEN 8 AND 9 THEN '8-9'
        ELSE 'Over 9'
    END AS sleep_time,
    ROUND(AVG(exercise_minutes_per_day),2) AS average_exercise,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_screen,
    ROUND(AVG(caffeine_intake_mg_per_day),2) AS average_caffeine,
    ROUND(AVG(stress_score)) AS average_stress,
    primary_device_used_at_night
FROM doom
GROUP BY sleep_time, primary_device_used_at_night
ORDER BY average_screen DESC
""").show(max_rows=100)
# Out:
# ┌────────────┬──────────────────┬────────────────┬──────────────────┬────────────────┬──────────────────────────────┐
# │ sleep_time │ average_exercise │ average_screen │ average_caffeine │ average_stress │ primary_device_used_at_night │
# │  varchar   │      double      │     double     │      double      │     double     │           varchar            │
# ├────────────┼──────────────────┼────────────────┼──────────────────┼────────────────┼──────────────────────────────┤
# │ Under 6    │             50.0 │         113.17 │             95.0 │            8.0 │ Laptop                       │
# │ Under 6    │            55.63 │         103.29 │           127.24 │            7.0 │ Smartphone                   │
# │ 6-7        │            48.32 │          64.92 │           121.36 │            6.0 │ Smartphone                   │
# │ 6-7        │            50.07 │          64.87 │           113.41 │            6.0 │ Laptop                       │
# │ 6-7        │            50.83 │          61.69 │             87.5 │            6.0 │ TV                           │
# │ Under 6    │             28.0 │           61.5 │            190.5 │            5.0 │ TV                           │
# │ 6-7        │            57.57 │          56.14 │           120.29 │            6.0 │ NULL                         │
# │ Under 6    │              9.0 │           55.0 │            117.0 │            6.0 │ Tablet                       │
# │ 6-7        │            54.32 │          50.73 │           128.64 │            6.0 │ Tablet                       │
# │ 7-8        │            66.85 │          49.08 │           115.75 │            7.0 │ NULL                         │
# │ 7-8        │            47.82 │          48.36 │           118.88 │            6.0 │ TV                           │
# │ 7-8        │            48.18 │          47.11 │           129.44 │            6.0 │ Laptop                       │
# │ 7-8        │            56.07 │          45.59 │           120.84 │            6.0 │ Smartphone                   │
# │ 7-8        │            54.45 │          45.07 │            88.21 │            6.0 │ Tablet                       │
# │ 8-9        │             49.5 │           44.5 │            59.75 │            6.0 │ NULL                         │
# │ 8-9        │             36.8 │          39.09 │           120.73 │            6.0 │ TV                           │
# │ Over 9     │            55.89 │          37.44 │            150.0 │            7.0 │ Smartphone                   │
# │ 8-9        │            56.69 │          37.11 │           142.56 │            7.0 │ Tablet                       │
# │ 8-9        │            59.78 │          35.35 │            132.9 │            6.0 │ Laptop                       │
# │ 8-9        │            55.66 │          33.19 │           127.72 │            6.0 │ Smartphone                   │
# │ Over 9     │             64.0 │           29.0 │             77.0 │            5.0 │ NULL                         │
# │ Over 9     │             78.0 │           28.0 │             12.0 │            4.0 │ TV                           │
# │ Over 9     │             59.0 │           25.5 │            118.5 │            6.0 │ Laptop                       │
# │ Over 9     │             61.0 │           13.5 │             79.0 │            7.0 │ Tablet                       │
# └────────────┴──────────────────┴────────────────┴──────────────────┴────────────────┴──────────────────────────────┘
#   24 rows                                                                                                 6 columns

# %%
#it doesn't seem too much like the type of screen matters, just how much screentime. We can see that the Under 6 hours of sleep group has high stress and high screentime with the laptop, I wonder if they are students? Let's find out.
sql("""
SELECT
    CASE
        WHEN sleep_hours_per_night < 6 THEN 'Under 6'
        WHEN sleep_hours_per_night BETWEEN 6 AND 7 THEN '6-7'
        WHEN sleep_hours_per_night BETWEEN 7 AND 8 THEN '7-8'
        WHEN sleep_hours_per_night BETWEEN 8 AND 9 THEN '8-9'
        ELSE 'Over 9'
    END AS sleep_time,
    ROUND(AVG(bedtime_screen_time_minutes),2) AS average_screen,
    ROUND(AVG(stress_score)) AS average_stress,
    primary_device_used_at_night AS device,
    occupation_status
FROM doom
WHERE device = 'Laptop'
GROUP BY sleep_time, primary_device_used_at_night, occupation_status
ORDER BY average_screen DESC
""").show(max_rows=100)
# Out:
# ┌────────────┬────────────────┬────────────────┬─────────┬────────────────────┐
# │ sleep_time │ average_screen │ average_stress │ device  │ occupation_status  │
# │  varchar   │     double     │     double     │ varchar │      varchar       │
# ├────────────┼────────────────┼────────────────┼─────────┼────────────────────┤
# │ Under 6    │          125.2 │            8.0 │ Laptop  │ Employed Full-time │
# │ 6-7        │           92.0 │            6.0 │ Laptop  │ Employed Part-time │
# │ 6-7        │           77.6 │            6.0 │ Laptop  │ Employed Full-time │
# │ 6-7        │          61.67 │            6.0 │ Laptop  │ Student            │
# │ 7-8        │          55.88 │            6.0 │ Laptop  │ Employed Full-time │
# │ Under 6    │           53.0 │            4.0 │ Laptop  │ Student            │
# │ 8-9        │           52.5 │            9.0 │ Laptop  │ NULL               │
# │ 6-7        │          52.33 │            5.0 │ Laptop  │ NULL               │
# │ 8-9        │           51.0 │            8.0 │ Laptop  │ Unemployed         │
# │ 7-8        │          46.83 │            6.0 │ Laptop  │ Employed Part-time │
# │ 6-7        │          45.67 │            8.0 │ Laptop  │ Unemployed         │
# │ 7-8        │           43.0 │            5.0 │ Laptop  │ Student            │
# │ 8-9        │          41.57 │            6.0 │ Laptop  │ Employed Full-time │
# │ 7-8        │           40.9 │            6.0 │ Laptop  │ Unemployed         │
# │ Over 9     │           38.0 │            7.0 │ Laptop  │ Unemployed         │
# │ 8-9        │           32.6 │            6.0 │ Laptop  │ Employed Part-time │
# │ 7-8        │          26.75 │            6.0 │ Laptop  │ NULL               │
# │ 8-9        │          21.71 │            6.0 │ Laptop  │ Student            │
# │ Over 9     │           13.0 │            4.0 │ Laptop  │ Employed Full-time │
# └────────────┴────────────────┴────────────────┴─────────┴────────────────────┘
#   19 rows                                                           5 columns

# %%
TBD
